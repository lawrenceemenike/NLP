# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import download
download('stopwords')
download('wordnet')
from nltk.corpus import stopwords
from wordcloud import WordCloud
import json
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to /home/rhyme/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /home/rhyme/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# task 1 - loading
data = pd.read_json('recipes.json', lines=True)

# %%
data.head(5)
# Out:
#                            Name  \
# 0                 Christmas pie
# 1  Simmer-&-stir Christmas cake
# 2            Christmas cupcakes
# 3                Christmas buns
# 4            Christmas cupcakes
#
#                                                  url  \
# 0  https://www.bbcgoodfood.com/recipes/2793/chris...
# 1  https://www.bbcgoodfood.com/recipes/1160/simme...
# 2  https://www.bbcgoodfood.com/recipes/72622/chri...
# 3  https://www.bbcgoodfood.com/recipes/1803633/ch...
# 4  https://www.bbcgoodfood.com/recipes/981634/chr...
#
#                                          Description            Author  \
# 0  Combine a few key Christmas flavours here to m...      Mary Cadogan
# 1  An easy-to-make alternative to traditional Chr...      Mary Cadogan
# 2  These beautiful and classy little cakes make l...     Sara Buenfeld
# 3  Paul Hollywood's fruit rolls can be made ahead...    Paul Hollywood
# 4  Made these for the second time today, and I ha...  Barney Desmazery
#
#                                          Ingredients  \
# 0  [2 tbsp olive oil, knob butter, 1 onion, finel...
# 1  [175g butter, chopped, 200g dark muscovado sug...
# 2  [200g dark muscovado sugar, 175g butter, chopp...
# 3  [500g strong white flour, plus extra for dusti...
# 4  [280g self-raising flour, 175g golden caster s...
#
#                                               Method
# 0  [Heat oven to 190C/fan 170C/gas 5. Heat 1 tbsp...
# 1  [Put the butter, sugar, fruit, zests, juice an...
# 2  [Tip the sugar, butter, dried fruit, whole che...
# 3  [Put the flour and 1 tsp salt into a large bow...
# 4  [Heat oven to 190C/170 fan/gas 5 and line a 12...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1617 entries, 0 to 1616
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         1617 non-null   object
#  1   url          1617 non-null   object
#  2   Description  1429 non-null   object
#  3   Author       1611 non-null   object
#  4   Ingredients  1617 non-null   object
#  5   Method       1617 non-null   object
# dtypes: object(6)
# memory usage: 75.9+ KB

# %%
data['Ingredients'].head(10)
# Out:
# 0    [2 tbsp olive oil, knob butter, 1 onion, finel...
# 1    [175g butter, chopped, 200g dark muscovado sug...
# 2    [200g dark muscovado sugar, 175g butter, chopp...
# 3    [500g strong white flour, plus extra for dusti...
# 4    [280g self-raising flour, 175g golden caster s...
# 5    [2 carrots, halved, ½ white cabbage, shredded,...
# 6    l double cream, 400g Greek yoghurt, 4 tbs...
# 7    [200g unsalted buttercut into cubes, plus extr...
# 8    l vodka, 500ml gingerwine, 1l cranberry j...
# 9    [145g pizza basemix, 6 tbsp tomato pasta sauce...
# Name: Ingredients, dtype: object

# %%
# task 2 - cleaning
data['Ingredients'] = data['Ingredients'].map(lambda x: re.sub(r'[^a-zA-Z ] ', ' ', str(x)))

# %%
data = data.dropna(subset=['Ingredients'])
data.head(5)
# Out:
#                            Name  \
# 0                 Christmas pie
# 1  Simmer-&-stir Christmas cake
# 2            Christmas cupcakes
# 3                Christmas buns
# 4            Christmas cupcakes
#
#                                                  url  \
# 0  https://www.bbcgoodfood.com/recipes/2793/chris...
# 1  https://www.bbcgoodfood.com/recipes/1160/simme...
# 2  https://www.bbcgoodfood.com/recipes/72622/chri...
# 3  https://www.bbcgoodfood.com/recipes/1803633/ch...
# 4  https://www.bbcgoodfood.com/recipes/981634/chr...
#
#                                          Description            Author  \
# 0  Combine a few key Christmas flavours here to m...      Mary Cadogan
# 1  An easy-to-make alternative to traditional Chr...      Mary Cadogan
# 2  These beautiful and classy little cakes make l...     Sara Buenfeld
# 3  Paul Hollywood's fruit rolls can be made ahead...    Paul Hollywood
# 4  Made these for the second time today, and I ha...  Barney Desmazery
#
#                                          Ingredients  \
# 0  [' tbsp olive oil' 'knob butter' ' onion finel...
# 1  ['175g butter chopped' '200g dark muscovado su...
# 2  ['200g dark muscovado sugar' '175g butter chop...
# 3  ['500g strong white flour plus extra for dusti...
# 4  ['280g self-raising flour' '175g golden caster...
#
#                                               Method
# 0  [Heat oven to 190C/fan 170C/gas 5. Heat 1 tbsp...
# 1  [Put the butter, sugar, fruit, zests, juice an...
# 2  [Tip the sugar, butter, dried fruit, whole che...
# 3  [Put the flour and 1 tsp salt into a large bow...
# 4  [Heat oven to 190C/170 fan/gas 5 and line a 12...

# %%
stop = stopwords.words('english') + ['tsp', 'tbsp', 'finely', 'extra', 'chopped']
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'tsp',
#  'tbsp',
#  'finely',
#  'extra',
#  'chopped']

# %%
# task 3 - remove encoding
def remove_encoding_word(word):
    word = str(word)
    word = word.encode('ASCII', 'ignore').decode('ASCII')
    return word

# %%
def remove_encoding_text(text):
    text = str(text)
    text = ' '.join(remove_encoding_word(word) for word in text.split() if word not in stop)
    return text

# %%
# task 4 - define lemmatizing
data['Ingredients'] = data['Ingredients'].apply(remove_encoding_text)

# %%
text = ' '.join(words for words in data['Ingredients'])
len(text)
# Out:
# 408959

# %%
lemma = WordNetLemmatizer().lemmatize

# %%
lemma('laughing')
# Out:
# 'laughing'

# %%
# task 5 - fit and transform text, with or without lemmatizing
def tokenize(document):
    tokens = [lemma(w) for w in document.split() if len(w) > 3 and w.isalpha()]
    return tokens

# %%
vectorizer = TfidfVectorizer(tokenizer = tokenize, ngram_range = ((2,2)),
                            stop_words = stop, strip_accents = 'unicode')

# %%
tdm = vectorizer.fit_transform(data['Ingredients'])
# Out:
# /home/rhyme/.local/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['doe'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
vectorizer.vocabulary_.items()
# Out:
# dict_items([('olive onion', 7420), ('onion sausagemeat', 7567), ('sausagemeat skinned', 9892), ('skinned zest', 10356), ('zest fresh', 13221), ('fresh white', 4402), ('white dried', 12786), ('dried apricot', 3644), ('apricot chestnut', 150), ('chestnut canned', 1858), ('canned fresh', 1387), ('fresh dried', 4333), ('dried cranberry', 3667), ('cranberry fresh', 2888), ('fresh boneless', 4310), ('boneless skinless', 775), ('skinless chicken', 10340), ('chicken pack', 1925), ('pack shortcrust', 7823), ('butter dark', 1176), ('dark muscovado', 3229), ('muscovado luxury', 7126), ('luxury mixed', 6567), ('mixed dried', 6989), ('dried fruit', 3683), ('fruit includes', 4496), ('includes mixed', 5598), ('mixed peel', 7030), ('peel glac', 8112), ('glac grated', 4707), ('grated zest', 4961), ('zest juice', 13231), ('juice grated', 5673), ('zest cherry', 13210), ('cherry brandy', 1810), ('brandy brandy', 845), ('brandy plus', 859), ('plus macadamia', 8748), ('macadamia large', 6570), ('large egg', 5876), ('egg lightly', 3878), ('lightly ground', 6356), ('ground plain', 5152), ('plain baking', 8526), ('baking ground', 339), ('ground mixed', 5140), ('mixed ground', 7004), ('ground ground', 5121), ('muscovado butter', 7102), ('butter luxury', 1210), ('dried glac', 3687), ('grated fresh', 4914), ('fresh root', 4376), ('root juice', 9549), ('juice dark', 5665), ('dark brandy', 3200), ('brandy orange', 857), ('orange pecannuts', 7664), ('pecannuts roughly', 8101), ('roughly large', 9650), ('egg ground', 3873), ('baking mixed', 343), ('mixed pack', 7027), ('pack used', 7840), ('used warm', 12336), ('warm apricotjam', 12620), ('apricotjam shredless', 191), ('shredless pack', 10245), ('pack fondant', 7770), ('fondant sugar', 4245), ('sugar gold', 11384), ('gold silver', 4741), ('silver gold', 10269), ('silver sugared', 10274), ('strong white', 11350), ('white flour', 12796), ('flour plus', 4205), ('plus sachet', 8786), ('sachet dried', 9758), ('dried unsalted', 3754), ('unsalted butter', 12164), ('butter softened', 1244), ('softened room', 10835), ('room unsalted', 9539), ('butter soft', 1243), ('soft brown', 10774), ('brown ground', 1033), ('ground dried', 5099), ('dried dried', 3674), ('dried caster', 3656), ('caster icing', 1576), ('golden caster', 4747), ('caster unsalted', 1635), ('butter natural', 1216), ('natural vanilla', 7235), ('vanilla unsalted', 12406), ('butter vanilla', 1259), ('vanilla icing', 12384), ('icing sugar', 5566), ('sugar green', 11387), ('green food', 5012), ('food christmas', 4248), ('christmas sweet', 2185), ('sweet sprinkle', 11553), ('sprinkle white', 11005), ('white chocolate', 12773), ('chocolate white', 2144), ('white chocolatebuttons', 12776), ('chocolatebuttons natural', 2149), ('natural colouring', 7219), ('colouring icing', 2646), ('icing pen', 5555), ('pen available', 8245), ('carrot white', 1483), ('white cabbage', 12764), ('cabbage pecan', 1310), ('pecan roughly', 8093), ('roughly spring', 9696), ('spring onion', 10994), ('onion pepper', 7552), ('pepper deseeded', 8252), ('deseeded maple', 3350), ('maple dijon', 6648), ('dijon olive', 3451), ('olive cider', 7371), ('double greek', 3549), ('greek lemon', 4994), ('lemon frozen', 6238), ('frozen mixed', 4467), ('mixed used', 7048), ('used black', 12228), ('black forest', 614), ('forest icing', 4280), ('icing pinch', 5556), ('unsalted buttercut', 12165), ('buttercut cube', 1270), ('cube plus', 3105), ('plus dark', 8688), ('dark chocolate', 3206), ('chocolate milk', 2117), ('milk chocolate', 6868), ('chocolate large', 2106), ('large golden', 5894), ('caster plain', 1608), ('plain cocoa', 8547), ('cocoa mixed', 2535), ('mixed sprig', 7042), ('sprig glac', 10963), ('glac caster', 4701), ('caster amaretti', 1511), ('amaretti biscuit', 66), ('biscuit chocolate', 578), ('chocolate used', 2142), ('used lindt', 12275), ('lindt gold', 6415), ('gold lustre', 4738), ('lustre icing', 6562), ('icing sugarfor', 5567), ('sugarfor chocolate', 11431), ('chocolate silver', 2133), ...

# %%
# task 6 -  get word frequencies and create wordcloud
tfidf_weights = [(word, tdm.getcol(idx).sum()) for word, idx in vectorizer.vocabulary_.items()]

# %%
tfidf_weights[0:10]
# Out:
# [('olive onion', 5.824471514115579),
#  ('onion sausagemeat', 0.2583004743669975),
#  ('sausagemeat skinned', 0.2583004743669975),
#  ('skinned zest', 0.2583004743669975),
#  ('zest fresh', 0.5822854727031399),
#  ('fresh white', 4.835339428289038),
#  ('white dried', 0.6984758317551231),
#  ('dried apricot', 6.028291416266405),
#  ('apricot chestnut', 0.2583004743669975),
#  ('chestnut canned', 0.2583004743669975)]

# %%
w = WordCloud(width=1500, height=1200, mode='RGBA', background_color='white',
             max_words=2000).fit_words(dict(tfidf_weights))

# %%
plt.figure(figsize=(20,15))
plt.imshow(w)
plt.axis('off')
plt.savefig('recipes_wordcloud.png')
